# %%
from bitcoin_deep_learning.metrics import *

# %%
plot_portolio_positions(positions=iterate_portfolio_positions(model = DummyModel(), 
                        df = ApiCall().read_local(data = 'train')))
