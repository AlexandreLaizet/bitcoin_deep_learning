# %% [markdown]
# ## Imports

# %%
#from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from bitcoin_deep_learning.call_api import ApiCall
from bitcoin_deep_learning.model import RnnDlModel, LinearRegressionBaselineModel, DummyModel
from bitcoin_deep_learning.trainer import train, read_result
from bitcoin_deep_learning.cross_val import get_cross_XY
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm import tqdm
from random import random
import joblib
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Getting data

# %%
train_df = ApiCall().read_local(data='train')#.drop(columns = '[%]_Bitcoin_growth_rate_on_Horizon=7')

# %%
X_train_list, Y_train_list, X_test_list,Y_test_list = get_cross_XY()

# %%
np.array(X_train_list).shape
# Out:
# (32, 263, 90, 32)

# %%
train_df.head(3)
# Out:
#          date  [AVG]_[NH]_mean_hash_rate  [+]_[NH]_Days_Till_Halving  \
# 0  2018-02-01               2.054109e+19                         830
# 1  2018-02-02               2.170824e+19                         829
# 2  2018-02-03               2.073919e+19                         828
#
#    [//]_[AV]_Stock-to-Flow_Ratio  [+]_[NH]_Circulating_Supply  \
# 0                    5642.903220                   16839700.0
# 1                    5641.695528                   16841800.0
# 2                    5641.015128                   16843775.0
#
#    [+]_[NH]_Issuance  [+]_[NH]_Number_of_Active_Addresses  \
# 0             2000.0                               842398
# 1             2100.0                               854253
# 2             1975.0                               714655
#
#    [+]_[NH]_Mean_Block_Interval  [+]_[NH]_Number_of_Transactions  \
# 0                           377                           257504
# 1                           385                           235750
# 2                           384                           194733
#
#    [+]_[NH]_Number_of_Addresses_with_a_Non-Zero_Balance  ...  \
# 0                                           27026398     ...
# 1                                           26955617     ...
# 2                                           26886977     ...
#
#    [%]_Bitcoin_growth_rate_on_Horizon=7  fear_greed_value  \
# 0                             -0.096230                30
# 1                             -0.013968                15
# 2                             -0.078603                40
#
#    [+]_[NH]_Number_of_Addresses_with_Balance_0.01 - 0.1  \
# 0                                            4226306
# 1                                            4198274
# 2                                            4173275
#
#    [+]_[NH]_Number_of_Addresses_with_Balance_0.1 - 1  \
# 0                                            1722331
# 1                                            1704275
# 2                                            1692828
#
#    [+]_[NH]_Number_of_Addresses_with_Balance_1 - 10  \
# 0                                            544769
# 1                                            543489
# 2                                            542447
#
#    [+]_[NH]_Number_of_Addresses_with_Balance_10 - 100  \
# 0                                             132314
# 1                                             132213
# 2                                             132021
#
#    [+]_[NH]_Number_of_Addresses_with_Balance_100 - 1k  \
# 0                                              15779
# 1                                              15815
# 2                                              15812
#
#    [+]_[NH]_Number_of_Addresses_with_Balance_1k - 10k  [+]_[T]_Bitcoin_Price  \
# 0                                               1529             9014.026207
# 1                                               1521             8799.121911
# 2                                               1523             9208.459919
#
#    [%]_Bitcoin_growth_rate_on_Horizon=7.1
# 0                               -0.096230
# 1                               -0.013968
# 2                               -0.078603
#
# [3 rows x 34 columns]

# %% [markdown]
# ## Data viz exploration

# %%
sns.histplot(train_df['[%]_Bitcoin_growth_rate_on_Horizon=7'], kde=True, edgecolor='w');

# %%
sns.histplot(train_df['[+]_[T]_Bitcoin_Price'], kde=True, edgecolor='w');

# %% [markdown]
# ## Ploting models

# %% [markdown]
# ### Plotting prediction per folds

# %%
def plot_predictions_models_all_folds(X_train_list, Y_train_list, X_test_list, Y_test_list, model):
    fig, axs = plt.subplots(nrows = len(X_train_list), ncols = 2, figsize = (17,150))
    for k in range(len(X_train_list)):
        X_train, y_train, X_test, y_test = X_train_list[k], Y_train_list[k], X_test_list[k], Y_test_list[k]
        #intuition too much regularization on the lasso
        model = model
        model.fit(model.preproc(X_test, X_train)[1], y_train)
        y_pred = model.run(X_test, X_train, y_train)
        axs[k, 0].plot(y_test, label = 'test')
        axs[k, 0].plot(y_pred, color = 'r', label = 'pred')
        axs[k, 0].set_title('Fitting of y_test, y_pred')
        axs[k, 0].legend()
        axs[k, 1].plot(y_train, label = 'train')
        axs[k, 1].set_title('Evolution of the y_train')
        axs[k, 1].legend();

# %%
plot_predictions_models_all_folds(X_train_list, Y_train_list, X_test_list, Y_test_list, LinearRegressionBaselineModel(alpha = 0.01 , l1_ratio = 0.001))

# %% [markdown]
# ### Strategies

# %%
from bitcoin_deep_learning.metrics import iterate_cross_val_results

# %%
def iterate_cross_val_results(model = LinearRegressionBaselineModel(alpha = 0.01 , l1_ratio = 0.001)):
    roi_hodler = []
    roi_trader = []
    roi_whale = []
    roi_hodler_whale = []
    roi_charles = []
    sharpe_hodler = []
    sharpe_trader = []
    sharpe_whale = []
    sharpe_hodler_whale = []
    sharpe_charles = []
    score_list = []

    Y_test_list, predictions, = cross_val(model, df)

    for reality, prediction in zip(realities,predictions):
        y_true, y_pred = reality, prediction

        roi_hodler.append(compute_roi(play_hodler_strategy(y_true, y_pred)))
        roi_trader.append(compute_roi(play_trader_strategy(y_true, y_pred)))
        roi_whale.append(compute_roi(play_whale_strategy(y_true, y_pred)))
        roi_hodler_whale.append(compute_roi(play_hodler_whale_strategy(y_true, y_pred)))
        roi_charles.append(compute_roi(play_charles_strategy(y_true, y_pred)))
        sharpe_hodler.append(compute_sharpe_ratio(play_hodler_strategy(y_true, y_pred)))
        sharpe_trader.append(compute_sharpe_ratio(play_trader_strategy(y_true, y_pred)))
        sharpe_whale.append(compute_sharpe_ratio(play_whale_strategy(y_true, y_pred)))
        sharpe_hodler_whale.append(compute_sharpe_ratio(play_hodler_whale_strategy(y_true, y_pred)))
        sharpe_charles.append(compute_sharpe_ratio(play_charles_strategy(y_true, y_pred)))
        #score_list.append(np.array(score).mean())

    return np.array(roi_hodler).mean(), np.array(roi_trader).mean(), np.array(roi_whale).mean(), np.array(roi_hodler_whale).mean(), np.array(roi_charles).mean(), np.array(sharpe_hodler).mean(), np.array(sharpe_trader).mean(), np.array(sharpe_whale).mean(), np.array(sharpe_hodler_whale).mean(), np.array(sharpe_charles).mean()

# %%
roi_hodler, roi_trader, roi_whale, roi_hodler_whale, roi_charles, sharpe_hodler, sharpe_trader, sharpe_whale, sharpe_hodler_whale, sharpe_charles = iterate_cross_val_results(model = LinearRegressionBaselineModel(alpha = 0.01 , l1_ratio = 0.001))
# Out:
# 100%|███████████████████████████████████████████| 32/32 [00:05<00:00,  6.24it/s]

# %%
print("---")
print("Hodler roi: ", roi_hodler)
print("Hodler sharpe ratio: ", sharpe_hodler)
print("---")
print("Trader roi: ", roi_trader)
print("Trader sharpe ratio: ", sharpe_trader)
print("---")
print("Whale roi: ", roi_whale)
print("Whale sharpe ratio: ", sharpe_whale)
print("---")
print("Hodler whale roi: ", roi_hodler_whale)
print("Hodler whale sharpe ratio: ", sharpe_hodler_whale)
print("---")
print("Charles roi: ", roi_charles)
print("Charles sharpe ratio: ", sharpe_charles)
# Out:
# ---
# Hodler roi:  -2.6357557995198757
# Hodler sharpe ratio:  -1.5678990112417894
# ---
# Trader roi:  -230.02817208864982
# Trader sharpe ratio:  -104.27845734937891
# ---
# Whale roi:  -230.02817208864982
# Whale sharpe ratio:  -104.27845734937891
# ---
# Hodler whale roi:  -123.45067665104882
# Hodler whale sharpe ratio:  -52.43146815716533
# ---
# Charles roi:  -230.02817208864982
# Charles sharpe ratio:  -104.27845734937891

# %% [markdown]
# ### Plotting scores on cross validated model

# %%
def plot_model_scores(model, train_df):
    scores = []
    for counter in range(10):
        #alpha = 0.1 * random()
        #l1 = 0.001 * random()
        # Instanciate model
        model = model
        # Train and Fit data using the crossval
        fold_score, score = train(model,train_df)
        scores = scores.append(score)
    fig, axs = plt.subplots(nrows = range(10), ncols = 1, figsize = (10,12))
    axs[0, 0].plot(scores, label = 'score')
    axs[0, 0].set_title('Model score plot')
    axs[0, 0].legend()

# %%
plot_model_scores(LinearRegressionBaselineModel(), train_df)
# Out:
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 14.62it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 14.61it/s]
# Training done
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/jq/gw28b5xj31l5gh19hr04gpmm0000gn/T/ipykernel_85838/234765873.py in <module>
# ----> 1 plot_model_scores(LinearRegressionBaselineModel(), train_df)
#
# /var/folders/jq/gw28b5xj31l5gh19hr04gpmm0000gn/T/ipykernel_85838/2308452483.py in plot_model_scores(model, train_df)
#       8         # Train and Fit data using the crossval
#       9         fold_score, score = train(model,train_df)
# ---> 10         scores = scores.append(score)
#      11     fig, axs = plt.subplots(nrows = range(10), ncols = 1, figsize = (10,12))
#      12     axs[0, 0].plot(scores, label = 'score')
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
model_regression.model.coef_
# Out:
# array([-0.00484787,  0.00606819,  0.00120077, -0.00625006,  0.00289792,
#        -0.00061098, -0.0041036 , -0.00219386, -0.00302848,  0.00447554,
#         0.02482501, -0.03144319,  0.        , -0.03294256, -0.0132189 ,
#         0.00150469, -0.        , -0.        , -0.01634933, -0.01207182,
#        -0.00720214, -0.0053081 ,  0.        , -0.01955083, -0.01971913,
#        -0.        ,  0.00221509, -0.00876869, -0.00518216, -0.01374838,
#         0.0079355 , -0.01207717])

# %%
y_pred = model_regression.run(X_test, X_train, y_train)

# %%
plt.plot(y_train);

# %%
plt.plot(y_test)
plt.plot(y_pred, color = 'r');

# %% [markdown]
# ## Analysing Coefs

# %% [markdown]
# ### Elastic Net training

# %%
train(model_regression, train_df)
None
# Out:
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 14.60it/s]
# Training done

# %% [markdown]
# ### VIF index

# %%
train_df_nodates = train_df.copy().drop(columns = 'date')#.drop(columns = bucket_list)

# %%
train_df_nodates_scaled = train_df_nodates.copy()

for feature in train_df_nodates_scaled.columns:
    mu = train_df_nodates[feature].mean()
    sigma = train_df_nodates[feature].std()
    train_df_nodates_scaled[feature] = train_df_nodates_scaled[feature].apply(lambda x: (x-mu)/sigma)

# %%
df = pd.DataFrame()

df["features"] = train_df_nodates_scaled.columns

df["vif_index"] = [vif(train_df_nodates_scaled.values, i) for i in range(train_df_nodates_scaled.shape[1])]

round(df.sort_values(by="vif_index", ascending = False),2).reset_index(drop = True)
# Out:
# /Users/chbro/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                                              features  vif_index
# 0              [%]_Bitcoin_growth_rate_on_Horizon=7.1        inf
# 1                [%]_Bitcoin_growth_rate_on_Horizon=7        inf
# 2                         [+]_[NH]_Circulating_Supply     536.34
# 3                            [$]_[BSB]_Realized_Price     470.79
# 4                       [//]_[AV]_Stock-to-Flow_Ratio     292.45
# 5   [+]_[NH]_Number_of_Addresses_with_Balance_0.01...     272.90
# 6   [+]_[NH]_Number_of_Addresses_with_a_Non-Zero_B...     256.78
# 7   [+]_[NH]_Number_of_Addresses_with_Balance_0.1 - 1     236.86
# 8                               [+]_[T]_Bitcoin_Price     174.84
# 9   [//]_[AV]_Market_Value_to_Realized_Value_Ratio...     146.87
# 10   [+]_[NH]_Number_of_Addresses_with_Balance_1 - 10     100.00
# 11                  [%]_[BSB]_Price_Drawdown_from_ATH      77.17
# 12  [%]_[BSB]_Percent_Balance_on_Exchanges_-_All_E...      53.46
# 13                           [//]_[AV]_Puell_Multiple      53.18
# 14                          [AVG]_[NH]_mean_hash_rate      51.34
# 15  [+]_[NH]_Number_of_Addresses_with_Balance_1k -...      50.44
# 16  [%]_[BSB]_Percent_of_Supply_Last_Active_1+_Yea...      45.50
# 17  [+]_[NH]_Number_of_Addresses_with_Balance_100 ...      34.38
# 18                                  [+]_[NH]_Issuance      30.93
# 19    [+]_[NH]_Number_of_Addresses_with_Balance_≥_10k      25.73
# 20  [+]_[NH]_Number_of_Addresses_with_Balance_10 -...      22.00
# 21                              [//]_[BSB]_Liveliness      19.80
# 22                         [+]_[NH]_Days_Till_Halving      15.30
# 23                     [//]_[BSB]_Realized_HODL_Ratio      11.04
# 24                [+]_[NH]_Number_of_Active_Addresses      10.96
# 25                    [+]_[NH]_Number_of_Transactions       9.16
# 26    [//]_[AV]_Realized_Profits-to-Value_(RPV)_Ratio       7.23
# 27        [$]_[BSB]_Net_Unrealized_Profit/Loss_(NUPL)       6.75
# 28                                   fear_greed_value       5.29
# 29  [$]_[BSB]_Exchange_Net_Position_Change_-_All_E...       3.95
# 30              [//]_[BSB]_Realized_Profit/Loss_Ratio       2.81
# 31                       [+]_[NH]_Mean_Block_Interval       2.34
# 32   [AVG]_[BSB]_Average_Spent_Output_Lifespan_(ASOL)       1.74

# %% [markdown]
# ### Coef matrix

# %%
len(train_df.columns)
# Out:
# 34

# %%
len(model_regression.model.coef_)
# Out:
# 32

# %%
coeff_matrix = pd.DataFrame(zip(train_df.columns,model_regression.model.coef_))
coeff_matrix = coeff_matrix.rename(columns={0: "features", 1: "coeff"})
coeff_matrix_absolute = coeff_matrix.copy()
coeff_matrix_absolute['coeff abs'] = coeff_matrix['coeff'].apply(abs)
coeff_matrix_absolute = coeff_matrix_absolute.drop(columns = 'coeff')
coeff_matrix_absolute.sort_values(by = 'coeff abs', ascending = False).reset_index(drop = True)
# Out:
#                                              features  coeff abs
# 0   [+]_[NH]_Number_of_Addresses_with_Balance_10 -...   0.026993
# 1                                                date   0.024846
# 2   [+]_[NH]_Number_of_Addresses_with_Balance_1k -...   0.020539
# 3                                   [+]_[NH]_Issuance   0.019811
# 4   [%]_[BSB]_Percent_Balance_on_Exchanges_-_All_E...   0.018352
# 5         [$]_[BSB]_Net_Unrealized_Profit/Loss_(NUPL)   0.018348
# 6                          [+]_[NH]_Days_Till_Halving   0.017226
# 7                            [$]_[BSB]_Realized_Price   0.015904
# 8   [//]_[AV]_Market_Value_to_Realized_Value_Ratio...   0.015739
# 9   [+]_[NH]_Number_of_Addresses_with_Balance_0.01...   0.015637
# 10                     [//]_[BSB]_Realized_HODL_Ratio   0.015514
# 11                                   fear_greed_value   0.013537
# 12                    [+]_[NH]_Number_of_Transactions   0.013488
# 13   [+]_[NH]_Number_of_Addresses_with_Balance_1 - 10   0.013086
# 14  [%]_[BSB]_Percent_of_Supply_Last_Active_1+_Yea...   0.012999
# 15  [+]_[NH]_Number_of_Addresses_with_Balance_100 ...   0.012880
# 16  [+]_[NH]_Number_of_Addresses_with_a_Non-Zero_B...   0.011440
# 17                  [%]_[BSB]_Price_Drawdown_from_ATH   0.011369
# 18    [//]_[AV]_Realized_Profits-to-Value_(RPV)_Ratio   0.010908
# 19   [AVG]_[BSB]_Average_Spent_Output_Lifespan_(ASOL)   0.010807
# 20                           [//]_[AV]_Puell_Multiple   0.007913
# 21                              [//]_[BSB]_Liveliness   0.007830
# 22                        [+]_[NH]_Circulating_Supply   0.006466
# 23               [%]_Bitcoin_growth_rate_on_Horizon=7   0.006199
# 24    [+]_[NH]_Number_of_Addresses_with_Balance_≥_10k   0.005323
# 25  [+]_[NH]_Number_of_Addresses_with_Balance_0.1 - 1   0.004291
# 26                       [+]_[NH]_Mean_Block_Interval   0.004223
# 27              [//]_[BSB]_Realized_Profit/Loss_Ratio   0.003119
# 28  [$]_[BSB]_Exchange_Net_Position_Change_-_All_E...   0.002657
# 29                [+]_[NH]_Number_of_Active_Addresses   0.002421
# 30                          [AVG]_[NH]_mean_hash_rate   0.000000
# 31                      [//]_[AV]_Stock-to-Flow_Ratio   0.000000

# %%
plt.figure(figsize = (22,20))
sns.heatmap(round(train_df.corr(),2), cmap = "coolwarm", annot = True, annot_kws = {"size":12});

# %%
train_df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8b34d_row0_col0, #T_8b34d_row1_col1, #T_8b34d_row2_col2, #T_8b34d_row3_col3, #T_8b34d_row4_col4, #T_8b34d_row5_col5, #T_8b34d_row6_col6, #T_8b34d_row7_col7, #T_8b34d_row8_col8, #T_8b34d_row9_col9, #T_8b34d_row10_col10, #T_8b34d_row11_col11, #T_8b34d_row12_col12, #T_8b34d_row13_col13, #T_8b34d_row14_col14, #T_8b34d_row15_col15, #T_8b34d_row16_col16, #T_8b34d_row17_col17, #T_8b34d_row18_col18, #T_8b34d_row19_col19, #T_8b34d_row20_col20, #T_8b34d_row21_col21, #T_8b34d_row22_col22, #T_8b34d_row23_col23, #T_8b34d_row23_col32, #T_8b34d_row24_col24, #T_8b34d_row25_col25, #T_8b34d_row26_col26, #T_8b34d_row27_col27, #T_8b34d_row28_col28, #T_8b34d_row29_col29, #T_8b34d_row30_col30, #T_8b34d_row31_col31, #T_8b34d_row32_col23, #T_8b34d_row32_col32 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col1, #T_8b34d_row1_col0, #T_8b34d_row1_col3, #T_8b34d_row10_col5, #T_8b34d_row15_col29, #T_8b34d_row16_col24, #T_8b34d_row17_col21, #T_8b34d_row18_col5, #T_8b34d_row19_col22, #T_8b34d_row21_col17 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_8b34d_row0_col2, #T_8b34d_row4_col29, #T_8b34d_row30_col19 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col3, #T_8b34d_row0_col26, #T_8b34d_row3_col30, #T_8b34d_row26_col0, #T_8b34d_row30_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col4, #T_8b34d_row0_col15, #T_8b34d_row0_col29, #T_8b34d_row4_col3, #T_8b34d_row18_col23, #T_8b34d_row18_col32, #T_8b34d_row21_col6, #T_8b34d_row29_col22, #T_8b34d_row29_col28 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col5 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col6, #T_8b34d_row5_col9, #T_8b34d_row15_col22 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col7, #T_8b34d_row1_col10, #T_8b34d_row8_col24, #T_8b34d_row15_col11, #T_8b34d_row17_col10, #T_8b34d_row21_col16, #T_8b34d_row27_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_8b34d_row0_col8, #T_8b34d_row8_col0 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col9, #T_8b34d_row14_col1, #T_8b34d_row26_col12, #T_8b34d_row30_col9 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col10, #T_8b34d_row2_col0, #T_8b34d_row5_col31, #T_8b34d_row20_col3, #T_8b34d_row20_col18, #T_8b34d_row21_col31, #T_8b34d_row22_col20, #T_8b34d_row31_col27 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col11, #T_8b34d_row1_col21, #T_8b34d_row11_col9, #T_8b34d_row11_col27, #T_8b34d_row16_col9, #T_8b34d_row23_col11, #T_8b34d_row32_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_8b34d_row0_col12, #T_8b34d_row8_col23, #T_8b34d_row8_col32, #T_8b34d_row9_col30, #T_8b34d_row12_col6, #T_8b34d_row20_col14 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col13, #T_8b34d_row4_col14, #T_8b34d_row22_col3 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_8b34d_row0_col14, #T_8b34d_row4_col7, #T_8b34d_row11_col30, #T_8b34d_row15_col2, #T_8b34d_row16_col14, #T_8b34d_row21_col4, #T_8b34d_row21_col12, #T_8b34d_row26_col11, #T_8b34d_row28_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_8b34d_row0_col16, #T_8b34d_row6_col2, #T_8b34d_row6_col25, #T_8b34d_row7_col8, #T_8b34d_row8_col22, #T_8b34d_row10_col20, #T_8b34d_row22_col7, #T_8b34d_row24_col13 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_8b34d_row0_col17, #T_8b34d_row18_col21, #T_8b34d_row20_col10 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_8b34d_row0_col18, #T_8b34d_row0_col20, #T_8b34d_row10_col7, #T_8b34d_row20_col26 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col19, #T_8b34d_row5_col19, #T_8b34d_row5_col26 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col21, #T_8b34d_row7_col25, #T_8b34d_row16_col31 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_8b34d_row0_col22, #T_8b34d_row2_col10, #T_8b34d_row6_col30, #T_8b34d_row11_col8, #T_8b34d_row23_col26, #T_8b34d_row30_col14, #T_8b34d_row32_col26 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_8b34d_row0_col23, #T_8b34d_row0_col32, #T_8b34d_row7_col6, #T_8b34d_row14_col19, #T_8b34d_row14_col31, #T_8b34d_row20_col4, #T_8b34d_row25_col12 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col24, #T_8b34d_row1_col11, #T_8b34d_row8_col21, #T_8b34d_row22_col2, #T_8b34d_row28_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_8b34d_row0_col25, #T_8b34d_row25_col0, #T_8b34d_row27_col30, #T_8b34d_row30_col27 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col27, #T_8b34d_row18_col31, #T_8b34d_row31_col18 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col28, #T_8b34d_row1_col22, #T_8b34d_row15_col12, #T_8b34d_row16_col28, #T_8b34d_row25_col22 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_8b34d_row0_col30, #T_8b34d_row8_col27, #T_8b34d_row27_col8 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_8b34d_row0_col31, #T_8b34d_row2_col3, #T_8b34d_row13_col2, #T_8b34d_row18_col13, #T_8b34d_row19_col3, #T_8b34d_row20_col8, #T_8b34d_row21_col19, #T_8b34d_row27_col10, #T_8b34d_row28_col14 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_8b34d_row1_col2, #T_8b34d_row20_col13, #T_8b34d_row21_col0, #T_8b34d_row21_col8 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_8b34d_row1_col4, #T_8b34d_row8_col4, #T_8b34d_row8_col9, #T_8b34d_row11_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_8b34d_row1_col5, #T_8b34d_row1_col19 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_8b34d_row1_col6, #T_8b34d_row18_col6, #T_8b34d_row23_col16, #T_8b34d_row27_col6, #T_8b34d_row32_col16 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_8b34d_row1_col7, #T_8b34d_row1_col9, #T_8b34d_row6_col7, #T_8b34d_row12_col17, #T_8b34d_row21_col28, #T_8b34d_row23_col17, #T_8b34d_row32_col17 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_8b34d_row1_col8, #T_8b34d_row2_col30 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_8b34d_row1_col12, #T_8b34d_row13_col29, #T_8b34d_row21_col15, #T_8b34d_row22_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_8b34d_row1_col13, #T_8b34d_row13_col17, #T_8b34d_row14_col27, #T_8b34d_row15_col13, #T_8b34d_row24_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_8b34d_row1_col14, #T_8b34d_row4_col31, #T_8b34d_row9_col20, #T_8b34d_row9_col22, #T_8b34d_row21_col23, #T_8b34d_row21_col32, #T_8b34d_row31_col28 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8b34d_row1_col15, #T_8b34d_row14_col16, #T_8b34d_row28_col21 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_8b34d_row1_col16, #T_8b34d_row21_col7, #T_8b34d_row23_col2, #T_8b34d_row32_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_8b34d_row1_col17, #T_8b34d_row3_col16, #T_8b34d_row6_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_8b34d_row1_col18, #T_8b34d_row3_col1, #T_8b34d_row13_col30, #T_8b34d_row17_col0, #T_8b34d_row19_col13, #T_8b34d_row24_col3, #T_8b34d_row24_col27 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_8b34d_row1_col20, #T_8b34d_row1_col31, #T_8b34d_row21_col22, #T_8b34d_row25_col1, #T_8b34d_row25_col13, #T_8b34d_row31_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_8b34d_row1_col23, #T_8b34d_row1_col32, #T_8b34d_row7_col23, #T_8b34d_row7_col32, #T_8b34d_row14_col18, #T_8b34d_row24_col23, #T_8b34d_row24_col32 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_8b34d_row1_col24, #T_8b34d_row2_col11, #T_8b34d_row31_col24 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_8b34d_row1_col25 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_8b34d_row1_col26, #T_8b34d_row17_col31 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_8b34d_row1_col27, #T_8b34d_row14_col7, #T_8b34d_row16_col19, #T_8b34d_row19_col17, #T_8b34d_row30_col2, #T_8b34d_row30_col18 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_8b34d_row1_col28, #T_8b34d_row9_col1, #T_8b34d_row13_col6, #T_8b34d_row15_col6, #T_8b34d_row15_col8, #T_8b34d_row15_col30, #T_8b34d_row23_col

# %% [markdown]
# ## Defining Dummy model as baseline

# %%
# Instanciate model
dummy_model = DummyModel()
# Train and Fit data using the crossval
train(dummy_model,train_df)
# Out:
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 14.26it/s]
# Training done
# ([104443796.71409,
#   136894896.907,
#   57789826.1821,
#   57571948.57084,
#   36307411.5702,
#   74567013.08173,
#   80072777.50872,
#   72418172.60801,
#   59181788.0284,
#   51308205.40128,
#   60591021.98488,
#   32626648.07279,
#   40880308.76564,
#   31323988.01489,
#   43549913.06879,
#   54124421.99118,
#   85738756.0788,
#   83004849.74182,
#   73315649.9243,
#   39252052.61965,
#   43965416.36385,
#   71334913.00391,
#   79765432.61877,
#   147999557.83168,
#   158509296.47573,
#   174562435.88332,
#   203875202.18098,
#   201701888.36384,
#   223167206.73096,
#   285640794.51113,
#   278941967.31325,
#   304205981.32192],
#  107769798.10733)

# %% [markdown]
# ## Elastic Net Tuning

# %%
# Instanciate Grid Search
for counter in range(10):
    alpha = 50 * random()
    l1 = 0.001
    # Instanciate model
    regression_model = LinearRegressionBaselineModel(alpha = alpha, l1_ratio = l1)
    # Train and Fit data using the crossval
    train(regression_model,train_df)
# Out:
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 14.91it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.04it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.11it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.04it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.07it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.09it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.07it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.07it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.06it/s]
# Training done
# 100%|███████████████████████████████████████████| 32/32 [00:02<00:00, 15.04it/s]
# Training done

# %% [markdown]
# ## RNN tuning

# %%
# Instanciate Grid Search
for counter in range(1):
    l1 = random() / 10
    l2 = random() / 10
    # Instanciate model
    rnn_model = RnnDlModel(L1 = l1, L2 = l2, epochs = 2, patience = 10)
    # Train and Fit data using the crossval
    fold_score, score = train(rnn_model,train_df)
# Out:
# 100%|███████████████████████████████████████████| 32/32 [01:56<00:00,  3.64s/it]
# Training done

# %%
print(fold_score, score)
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan] nan

# %% [markdown]
# ## Exporting and viewing results

# %%
df_result = read_result()
df_result.sort_values(by="mean_score", ascending = False)
# Out:
#          name                                         fold_score  \
# 15      Dummy  [104443796.71409, 136894896.907, 57789826.1821...
# 1       Dummy  [104443796.71409, 136894896.907, 57789826.1821...
# 0   LinearReg  [854.24552, 622.42861, 493.03903, 216.84037, 4...
# 14  LinearReg  [854.24552, 622.42861, 493.03903, 216.84037, 4...
# 21  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 20  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 16  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 12  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 11  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 9   LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 19  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 8   LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 7   LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 22  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 5   LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 23  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 24  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 2   LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 18  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 25  LinearReg  [825.38041, 688.86639, 208.91283, 156.25223, 1...
# 6   LinearReg  [825.38041, 687.82459, 208.30006, 155.11371, 1...
# 10  LinearReg  [825.38041, 685.51858, 207.37036, 152.33121, 1...
# 4   LinearReg  [825.38041, 684.76455, 207.18741, 151.66407, 1...
# 17  LinearReg  [825.26702, 681.91871, 206.10278, 148.36424, 1...
# 3   LinearReg  [830.19721, 636.864, 191.9049, 108.96573, 139....
# 13  LinearReg  [830.27614, 651.19682, 196.78884, 119.99793, 1...
# 26        RNN  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 27        RNN  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#       mean_score     min_score     max_score  \
# 15  1.077698e+08  3.132399e+07  3.042060e+08
# 1   1.077698e+08  3.132399e+07  3.042060e+08
# 0   4.092938e+02  1.168868e+02  1.708942e+03
# 14  4.092938e+02  1.168868e+02  1.708942e+03
# 21  1.879553e+02  9.653568e+01  8.253804e+02
# 20  1.879553e+02  9.653568e+01  8.253804e+02
# 16  1.879553e+02  9.653568e+01  8.253804e+02
# 12  1.879553e+02  9.653568e+01  8.253804e+02
# 11  1.879553e+02  9.653568e+01  8.253804e+02
# 9   1.879553e+02  9.653568e+01  8.253804e+02
# 19  1.879553e+02  9.653568e+01  8.253804e+02
# 8   1.879553e+02  9.653568e+01  8.253804e+02
# 7   1.879553e+02  9.653568e+01  8.253804e+02
# 22  1.879553e+02  9.653568e+01  8.253804e+02
# 5   1.879553e+02  9.653568e+01  8.253804e+02
# 23  1.879553e+02  9.653568e+01  8.253804e+02
# 24  1.879553e+02  9.653568e+01  8.253804e+02
# 2   1.879553e+02  9.653568e+01  8.253804e+02
# 18  1.879553e+02  9.653568e+01  8.253804e+02
# 25  1.878676e+02  9.653568e+01  8.253804e+02
# 6   1.874265e+02  9.653568e+01  8.253804e+02
# 10  1.871397e+02  9.653568e+01  8.253804e+02
# 4   1.870863e+02  9.653568e+01  8.253804e+02
# 17  1.868159e+02  9.653463e+01  8.252670e+02
# 3   1.862314e+02  9.638049e+01  8.301972e+02
# 13  1.857374e+02  9.645201e+01  8.302761e+02
# 26           NaN           NaN           NaN
# 27           NaN           NaN           NaN
#
#                                           hyperparams            date
# 15                                                NaN  08-03 11:03:45
# 1                                                 NaN  08-03 11:02:20
# 0                   {'alpha': 0.1, 'l1_ratio': 0.001}  08-03 11:02:14
# 14                  {'alpha': 0.1, 'l1_ratio': 0.001}  08-03 11:03:39
# 21    {'alpha': 26.48286261231705, 'l1_ratio': 0.001}  08-03 11:03:58
# 20   {'alpha': 26.559064262705206, 'l1_ratio': 0.001}  08-03 11:03:56
# 16    {'alpha': 26.63228447585158, 'l1_ratio': 0.001}  08-03 11:03:47
# 12    {'alpha': 21.10384470374208, 'l1_ratio': 0.001}  08-03 11:02:44
# 11   {'alpha': 25.327487599672015, 'l1_ratio': 0.001}  08-03 11:02:41
# 9    {'alpha': 27.354675224599617, 'l1_ratio': 0.001}  08-03 11:02:37
# 19    {'alpha': 32.89473988759835, 'l1_ratio': 0.001}  08-03 11:03:53
# 8     {'alpha': 44.12711163773888, 'l1_ratio': 0.001}  08-03 11:02:35
# 7    {'alpha': 23.754321768663917, 'l1_ratio': 0.001}  08-03 11:02:33
# 22    {'alpha': 46.91798598164864, 'l1_ratio': 0.001}  08-03 11:04:00
# 5     {'alpha': 41.58403682801464, 'l1_ratio': 0.001}  08-03 11:02:28
# 23    {'alpha': 46.64573820067481, 'l1_ratio': 0.001}  08-03 11:04:02
# 24    {'alpha': 40.08038741185616, 'l1_ratio': 0.001}  08-03 11:04:04
# 2    {'alpha': 27.866832513282024, 'l1_ratio': 0.001}  08-03 11:02:22
# 18    {'alpha': 29.47077235274756, 'l1_ratio': 0.001}  08-03 11:03:51
# 25   {'alpha': 13.061674354350439, 'l1_ratio': 0.001}  08-03 11:04:06
# 6     {'alpha': 8.540551834832694, 'l1_ratio': 0.001}  08-03 11:02:31
# 10    {'alpha': 7.084945418500144, 'l1_ratio': 0.001}  08-03 11:02:39
# 4      {'alpha': 6.85351851836703, 'l1_ratio': 0.001}  08-03 11:02:26
# 17    {'alpha': 5.887742038262367, 'l1_ratio': 0.001}  08-03 11:03:49
# 3    {'alpha': 2.4183006592986445, 'l1_ratio': 0.001}  08-03 11:02:24
# 13   {'alpha': 2.9666452484707504, 'l1_ratio': 0.001}  08-03 11:02:46
# 26  {'L1': 0.014709231629547303, 'L2': 0.082093539...  08-03 11:08:17
# 27  {'L1': 0.08906934761882243, 'L2': 0.0080849095...  08-03 11:12:07

# %% [markdown]
# ## Notes

# %%
# take mean on the week on linear regression and inspect the weights
# create a btc trajectory on linear trend +2% (test unitaire) => check outcome of strategies in a basic situation
# y_diff to try to improve MAPE
# Check colinearity on coefficients => heatmap ?
# RNN, can try with less features from 2015 if we lack of simples (263 sized sequences, might not be enough)
# l1 is a feature selector that can help tune the RNN
#Feature importance
#if you don't have enough variance, you can leave them out
#Vif analysis on X
#checking the y permutation importance (suffling and checking impact on R2)
#Reco => vif on features & lasso importance
#shuffle on each folds axis = 0 np.array.shuffle()

#keep the mae of the y_diff
#Redo the coeffs
#Finetuning of the models
#plotting distribution of the mae as well
